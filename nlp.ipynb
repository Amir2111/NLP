# %%
a = input()
# apple

ls = []
# a = 'abz'

for i in a:
  if i == 'z':
    i = 'a'
    ls.append(i)
  elif i == 'z':
    i = 'A'
    ls.append(i)
  else:
    b = ord(i)
    b = b+1
    b = chr(b)
    ls.append(b)
print(ls)
# Out:
# A
# ['B']
